# %% [markdown]
# # HOUSING PROJECT

# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
import warnings 
warnings.filterwarnings('ignore')

# %%
dd=pd.read_csv('test.csv')

# %%
df=pd.DataFrame(data=dd)

# %%
df
# Out:
#        Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0     337          20       RL         86.0    14157   Pave   NaN      IR1
# 1    1018         120       RL          NaN     5814   Pave   NaN      IR1
# 2     929          20       RL          NaN    11838   Pave   NaN      Reg
# 3    1148          70       RL         75.0    12000   Pave   NaN      Reg
# 4    1227          60       RL         86.0    14598   Pave   NaN      IR1
# ..    ...         ...      ...          ...      ...    ...   ...      ...
# 287    83          20       RL         78.0    10206   Pave   NaN      Reg
# 288  1048          20       RL         57.0     9245   Pave   NaN      IR2
# 289    17          20       RL          NaN    11241   Pave   NaN      IR1
# 290   523          50       RM         50.0     5000   Pave   NaN      Reg
# 291  1379         160       RM         21.0     1953   Pave   NaN      Reg
#
# ...

# %% [markdown]
# ## DUPLICATE VALUES CHECK

# %%
DF=df.drop_duplicates()

# %%
DF
# Out:
#        Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0     337          20       RL         86.0    14157   Pave   NaN      IR1
# 1    1018         120       RL          NaN     5814   Pave   NaN      IR1
# 2     929          20       RL          NaN    11838   Pave   NaN      Reg
# 3    1148          70       RL         75.0    12000   Pave   NaN      Reg
# 4    1227          60       RL         86.0    14598   Pave   NaN      IR1
# ..    ...         ...      ...          ...      ...    ...   ...      ...
# 287    83          20       RL         78.0    10206   Pave   NaN      Reg
# 288  1048          20       RL         57.0     9245   Pave   NaN      IR2
# 289    17          20       RL          NaN    11241   Pave   NaN      IR1
# 290   523          50       RM         50.0     5000   Pave   NaN      Reg
# 291  1379         160       RM         21.0     1953   Pave   NaN      Reg
#
# ...

# %% [markdown]
# ### NO DUPLICATE VALUES FOUND

# %% [markdown]
# ## IDENTIFICATION OF VARIABLES & DATA TYPES

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 292 entries, 0 to 291
# Data columns (total 80 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             292 non-null    int64
#  1   MSSubClass     292 non-null    int64
#  2   MSZoning       292 non-null    object
#  3   LotFrontage    247 non-null    float64
#  4   LotArea        292 non-null    int64
#  5   Street         292 non-null    object
#  6   Alley          14 non-null     object
#  7   LotShape       292 non-null    object
#  8   LandContour    292 non-null    object
#  9   Utilities      292 non-null    object
#  10  LotConfig      292 non-null    object
#  11  LandSlope      292 non-null    object
#  12  Neighborhood   292 non-null    object
#  13  Condition1     292 non-null    object
#  14  Condition2     292 non-null    object
#  15  BldgType       292 non-null    object
#  16  HouseStyle     292 non-null    object
# ...

# %% [markdown]
# ### THERE ARE MULTIPLE COLUMNS WITH MISSING VALUES, WE WILL IMPUTE THEM AND SOME COLUMNS HAVE MORE THAN 40% DATA MISSING, HENCE WE WILL DELETE THEM

# %%
df1=df.drop(columns=['MiscFeature','Fence','PoolQC','FireplaceQu','Alley'],axis=1)

# %%
df1
# Out:
#        Id  MSSubClass MSZoning  LotFrontage  LotArea Street LotShape  \
# 0     337          20       RL         86.0    14157   Pave      IR1
# 1    1018         120       RL          NaN     5814   Pave      IR1
# 2     929          20       RL          NaN    11838   Pave      Reg
# 3    1148          70       RL         75.0    12000   Pave      Reg
# 4    1227          60       RL         86.0    14598   Pave      IR1
# ..    ...         ...      ...          ...      ...    ...      ...
# 287    83          20       RL         78.0    10206   Pave      Reg
# 288  1048          20       RL         57.0     9245   Pave      IR2
# 289    17          20       RL          NaN    11241   Pave      IR1
# 290   523          50       RM         50.0     5000   Pave      Reg
# 291  1379         160       RM         21.0     1953   Pave      Reg
#
#     LandContour Utilities LotConfig  ... OpenPorchSF EnclosedPorch 3SsnPorch  \
# ...

# %% [markdown]
# ## CHECKING THE VARIOUS COLUMNS

# %%
df1.columns
# Out:
# Index(['Id', 'MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street',
#        'LotShape', 'LandContour', 'Utilities', 'LotConfig', 'LandSlope',
#        'Neighborhood', 'Condition1', 'Condition2', 'BldgType', 'HouseStyle',
#        'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd', 'RoofStyle',
#        'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType', 'MasVnrArea',
#        'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual', 'BsmtCond',
#        'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1', 'BsmtFinType2',
#        'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating', 'HeatingQC',
#        'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF', 'LowQualFinSF',
#        'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath', 'HalfBath',
#        'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual', 'TotRmsAbvGrd',
#        'Functional', 'Fireplaces', 'GarageType', 'GarageYrBlt', 'GarageFinish',
#        'GarageCars', 'GarageArea', 'GarageQual', 'GarageCond', 'PavedDrive',
# ...

# %% [markdown]
# ## UNIQUE VALUES & COUNT OF EACH COLUMN

# %%
df1['Id'].unique()
# Out:
# array([ 337, 1018,  929, 1148, 1227,  650, 1453,  152,  427,  776,   30,
#        1425,  423, 1185,  775,  391, 1408,  513, 1266,  173, 1150,  797,
#         137,  706, 1377, 1177, 1456,  369, 1421,  999, 1217,  937,  769,
#         831,  678,  574,  921, 1292, 1277,  676,  108,  424,  823, 1455,
#         377, 1256, 1120,  265, 1158,  725, 1378, 1139,  122,  515,  518,
#        1214,  443,  903,   53,  469,   76, 1142, 1222,  851,  334, 1008,
#          19,  339, 1118,  834, 1176,  945, 1415,  911,  388,  747,  620,
#         386,  818,  539,  535, 1399,  571,   38,  850, 1032, 1433, 1354,
#        1072,  371, 1242,  681,  290,  973,  989,  484, 1240, 1125, 1143,
#        1340, 1343,  936, 1151, 1380, 1190,  635,   47,  729, 1434,  472,
#        1156, 1352,  717,  385, 1334,  243,   39, 1168,  214,  647,  490,
#         512, 1181, 1451, 1428,  767, 1250,  855, 1001,   49,   25, 1058,
#          24,  758, 1060, 1110, 1057,  491,  378, 1429,   55,  770,  737,
# ...

# %%
df1['Id'].value_counts()
# Out:
# 337     1
# 960     1
# 1351    1
# 761     1
# 1000    1
#        ..
# 1240    1
# 484     1
# 989     1
# 973     1
# 1379    1
# Name: Id, Length: 292, dtype: int64

# %%
df1['MSSubClass'].unique()
# Out:
# array([ 20, 120,  70,  60, 180,  80,  30,  50, 160, 190,  90,  85,  45,
#         75,  40])

# %%
df1['MSSubClass'].value_counts()
# Out:
# 20     108
# 60      55
# 50      31
# 120     18
# 30      17
# 160     16
# 80      15
# 90      11
# 70       7
# 180      4
# 190      4
# 45       2
# 75       2
# 85       1
# 40       1
# Name: MSSubClass, dtype: int64

# %%
df1['MSZoning'].unique()
# Out:
# array(['RL', 'RM', 'FV', 'C (all)'], dtype=object)

# %%
df1['MSZoning'].value_counts()
# Out:
# RL         223
# RM          55
# FV          13
# C (all)      1
# Name: MSZoning, dtype: int64

# %%
df1['LotFrontage'].unique()
# Out:
# array([ 86.,  nan,  75.,  21.,  35., 107.,  32.,  60., 100.,  50., 110.,
#         70.,  44.,  71.,  52.,  37.,  62.,  78.,  90.,  68.,  67.,  80.,
#         76.,  24.,  57.,  30.,  34.,  55.,  79.,  63.,  98.,  36.,  59.,
#         66.,  91.,  85.,  64.,  72.,  43.,  74., 102.,  56.,  83.,  77.,
#        120.,  73.,  48.,  93.,  92.,  58.,  40.,  33.,  47.,  51., 138.,
#        124.,  42.,  89., 105.,  65.,  45.,  61., 137.,  96., 150.,  69.])

# %%
df1['LotFrontage'].value_counts()
# Out:
# 60.0     32
# 85.0     14
# 50.0     13
# 70.0     12
# 21.0      9
# 65.0      9
# 80.0      9
# 75.0      7
# 52.0      6
# 63.0      6
# 78.0      6
# 66.0      5
# 64.0      5
# 57.0      5
# 43.0      4
# 72.0      4
# 55.0      4
# 100.0     4
# 40.0      4
# 74.0      4
# 102.0     3
# 48.0      3
# 93.0      3
# 79.0      3
# 86.0      3
# 110.0     3
# 67.0      3
# 90.0      3
# 68.0      3
# 44.0      3
# 76.0      3
# 24.0      3
# 56.0      2
# 83.0      2
# 58.0      2
# 92.0      2
# 32.0      2
# 35.0      2
# 73.0      2
# 47.0      2
# 96.0      2
# 107.0     2
# 42.0      2
# 51.0      2
# 37.0      2
# 62.0      2
# 91.0      2
# 98.0      2
# 105.0     1
# 150.0     1
# 61.0      1
# 45.0      1
# 137.0     1
# 89.0      1
# 34.0      1
# 124.0     1
# 138.0     1
# 33.0      1
# 30.0      1
# 120.0     1
# 77.0      1
# 71.0      1
# 59.0      1
# 36.0      1
# 69.0      1
# Name: LotFrontage, dtype: int64

# %%
df1['Street'].unique()
# Out:
# array(['Pave', 'Grvl'], dtype=object)

# %%
df1['Street'].value_counts()
# Out:
# Pave    290
# Grvl      2
# Name: Street, dtype: int64

# %%
df1['LotArea'].unique()
# Out:
# array([ 14157,   5814,  11838,  12000,  14598,   1936,   3675,  13891,
#         12800,   4500,   6324,   9503,  21750,  35133,  14226,   8405,
#          8780,   9100,   3735,   5306,   9000,   8197,  10355,   5600,
#          6292,   6951,   7917,   7800,  11700,   9786,   8930,  10083,
#         11900,   9022,   9967,   8462,   1680,  12936,   2289,   6000,
#          9200,  12394,   7500,   8846,   6240,   7560,   5232,   5001,
#         13286,  10998,   9819,   6060,  10594,  10208,  10246,   7875,
#          8472,  11428,   1596,  10304,   8250,   4435,   8198,   2217,
#         13695,  14145,   9764,  10004,  10678,  14375,  13053,  11600,
#          7200,   8795,  12244,   3182,  13265,  11553,   9056,  13101,
#          8532,   9600,  15863,  10800,  14720,   8121,   9849,   8012,
#          8730,   7892,  12046,   9037,   9125,   9965,   9560,   9375,
#          5825,   8280,   9735,   6979,  12822,  11475,  10261,  11952,
# ...

# %%
df1['LotArea'].value_counts()
# Out:
# 7200     7
# 1680     4
# 5400     3
# 8450     3
# 9600     3
#         ..
# 8280     1
# 9735     1
# 6979     1
# 12822    1
# 1953     1
# Name: LotArea, Length: 249, dtype: int64

# %%
df1['LotShape'].unique()
# Out:
# array(['IR1', 'Reg', 'IR3', 'IR2'], dtype=object)

# %%
df1['LotShape'].value_counts()
# Out:
# Reg    185
# IR1     94
# IR2      9
# IR3      4
# Name: LotShape, dtype: int64

# %%
df1['LandContour'].unique()
# Out:
# array(['HLS', 'Lvl', 'Bnk', 'Low'], dtype=object)

# %%
df1['LandContour'].value_counts()
# Out:
# Lvl    265
# Bnk     13
# HLS      8
# Low      6
# Name: LandContour, dtype: int64

# %%
df1['Utilities'].unique()
# Out:
# array(['AllPub', 'NoSeWa'], dtype=object)

# %%
df1['Utilities'].value_counts()
# Out:
# AllPub    291
# NoSeWa      1
# Name: Utilities, dtype: int64

# %%
df1['LotConfig'].unique()
# Out:
# array(['Corner', 'CulDSac', 'Inside', 'FR2', 'FR3'], dtype=object)

# %%
df1['LotConfig'].value_counts()
# Out:
# Inside     210
# Corner      41
# CulDSac     25
# FR2         14
# FR3          2
# Name: LotConfig, dtype: int64

# %%
df1['LandSlope'].unique()
# Out:
# array(['Gtl', 'Mod', 'Sev'], dtype=object)

# %%
df1['LandSlope'].value_counts()
# Out:
# Gtl    277
# Mod     14
# Sev      1
# Name: LandSlope, dtype: int64

# %%
df1['Neighborhood'].unique()
# Out:
# array(['StoneBr', 'CollgCr', 'Crawfor', 'Somerst', 'MeadowV', 'Edwards',
#        'NridgHt', 'SawyerW', 'Mitchel', 'BrkSide', 'NAmes', 'Timber',
#        'OldTown', 'Sawyer', 'IDOTRR', 'SWISU', 'Gilbert', 'NWAmes',
#        'BrDale', 'NPkVill', 'NoRidge', 'Blmngtn', 'Veenker', 'ClearCr'],
#       dtype=object)

# %%
df1['Neighborhood'].value_counts()
# Out:
# NAmes      43
# CollgCr    32
# OldTown    27
# Somerst    18
# Edwards    17
# NridgHt    16
# Gilbert    15
# Mitchel    15
# Timber     14
# Sawyer     14
# NWAmes     14
# MeadowV     8
# SawyerW     8
# BrkSide     8
# IDOTRR      7
# NoRidge     6
# StoneBr     6
# Crawfor     6
# BrDale      5
# SWISU       4
# ClearCr     4
# Blmngtn     2
# Veenker     2
# NPkVill     1
# Name: Neighborhood, dtype: int64

# %%
df1['Condition1'].unique()
# Out:
# array(['Norm', 'Feedr', 'Artery', 'RRAe', 'RRNn', 'PosN', 'RRAn', 'PosA'],
#       dtype=object)

# %%
df1['Condition1'].value_counts()
# Out:
# Norm      255
# Feedr      14
# Artery     10
# RRAn        6
# RRAe        2
# PosN        2
# PosA        2
# RRNn        1
# Name: Condition1, dtype: int64

# %%
df1['Condition2'].unique()
# Out:
# array(['Norm', 'RRNn'], dtype=object)

# %%
df1['Condition2'].value_counts()
# Out:
# Norm    291
# RRNn      1
# Name: Condition2, dtype: int64

# %%
df1['BldgType'].unique()
# Out:
# array(['1Fam', 'TwnhsE', 'Twnhs', '2fmCon', 'Duplex'], dtype=object)

# %%
df1['BldgType'].value_counts()
# Out:
# 1Fam      239
# TwnhsE     24
# Twnhs      14
# Duplex     11
# 2fmCon      4
# Name: BldgType, dtype: int64

# %%
df1['HouseStyle'].unique()
# Out:
# array(['1Story', '2Story', 'SFoyer', 'SLvl', '1.5Fin', '1.5Unf', '2.5Fin',
#        '2.5Unf'], dtype=object)

# %%
df1['HouseStyle'].value_counts()
# Out:
# 1Story    148
# 2Story     84
# 1.5Fin     33
# SLvl       18
# SFoyer      5
# 1.5Unf      2
# 2.5Fin      1
# 2.5Unf      1
# Name: HouseStyle, dtype: int64

# %%
df1['OverallQual'].unique()
# Out:
# array([ 9,  8,  7,  6,  4,  5,  3, 10])

# %%
df1['OverallQual'].value_counts()
# Out:
# 5     83
# 6     79
# 7     59
# 8     30
# 4     23
# 9     11
# 3      4
# 10     3
# Name: OverallQual, dtype: int64

# %%
df1['OverallCond'].unique()
# Out:
# array([5, 7, 6, 4, 8, 9, 3])

# %%
df1['OverallCond'].value_counts()
# Out:
# 5    181
# 6     43
# 7     33
# 4     14
# 8     11
# 9      6
# 3      4
# Name: OverallCond, dtype: int64

# %%
df1['YearBuilt'].unique()
# Out:
# array([2005, 1984, 2001, 1941, 2007, 1970, 1989, 1998, 1927, 1958, 1954,
#        1963, 2006, 1900, 1985, 1999, 1987, 1920, 1977, 1967, 1930, 1968,
#        1922, 1978, 2003, 2004, 1957, 1924, 2000, 1994, 1972, 1948, 1996,
#        1931, 1959, 1925, 1939, 1926, 1965, 1973, 1976, 1964, 1992, 1923,
#        1960, 2002, 1950, 1995, 1980, 1915, 1979, 1962, 1890, 1938, 1953,
#        1990, 1974, 1945, 1988, 1955, 1952, 1932, 1940, 1956, 2009, 1971,
#        1947, 1975, 1946, 1997, 1966, 2008, 1993, 1914, 1969, 1885, 1916,
#        1872, 1928, 1935, 1910, 1919, 1892, 1982])

# %%
df1['YearBuilt'].value_counts()
# Out:
# 2004    17
# 2005    13
# 2003    12
# 2006    10
# 1976    10
#         ..
# 1956     1
# 1940     1
# 1932     1
# 1952     1
# 1982     1
# Name: YearBuilt, Length: 84, dtype: int64

# %%
df1['YearRemodAdd'].unique()
# Out:
# array([2006, 1984, 2001, 1950, 2007, 1970, 2005, 2008, 1989, 1998, 1983,
#        1954, 1963, 1985, 1958, 1999, 1987, 1988, 1977, 1967, 2000, 1968,
#        1978, 2003, 1957, 1994, 1972, 1996, 1959, 2004, 1960, 1997, 1992,
#        1973, 1976, 1964, 2002, 1982, 1965, 1990, 1980, 1979, 1953, 1962,
#        1995, 1991, 1974, 1952, 1955, 1956, 2009, 1971, 1975, 1966, 1969,
#        1993, 2010])

# %%
df1['YearRemodAdd'].value_counts()
# Out:
# 1950    32
# 2004    16
# 2005    16
# 2006    15
# 2003    14
# 2007    12
# 2000    11
# 1976    10
# 1998    10
# 2008    10
# 2002     7
# 1995     7
# 1977     7
# 1997     6
# 1970     6
# 1994     6
# 1968     6
# 1996     5
# 1972     5
# 1959     5
# 1999     5
# 2001     5
# 1965     4
# 1964     4
# 1992     4
# 1990     4
# 1958     3
# 1985     3
# 2009     3
# 1980     3
# 1954     3
# 1973     3
# 1987     3
# 1974     3
# 1978     3
# 1960     3
# 1971     2
# 1966     2
# 1955     2
# 1953     2
# 1967     2
# 1988     2
# 1989     2
# 1963     2
# 1984     2
# 1979     1
# 1962     1
# 1982     1
# 1991     1
# 1952     1
# 1983     1
# 1956     1
# 1975     1
# 1957     1
# 1969     1
# 1993     1
# 2010     1
# Name: YearRemodAdd, dtype: int64

# %%
df1['RoofStyle'].unique()
# Out:
# array(['Hip', 'Gable', 'Gambrel', 'Mansard', 'Flat'], dtype=object)

# %%
df1['RoofStyle'].value_counts()
# Out:
# Gable      226
# Hip         61
# Gambrel      2
# Mansard      2
# Flat         1
# Name: RoofStyle, dtype: int64

# %%
df1['RoofMatl'].unique()
# Out:
# array(['CompShg', 'WdShake', 'Tar&Grv'], dtype=object)

# %%
df1['RoofMatl'].value_counts()
# Out:
# CompShg    290
# WdShake      1
# Tar&Grv      1
# Name: RoofMatl, dtype: int64

# %%
df1['Exterior1st'].unique()
# Out:
# array(['VinylSd', 'HdBoard', 'MetalSd', 'CemntBd', 'Wd Sdng', 'Plywood',
#        'BrkFace', 'AsbShng', 'WdShing', 'BrkComm', 'Stucco', 'CBlock'],
#       dtype=object)

# %%
df1['Exterior1st'].value_counts()
# Out:
# VinylSd    119
# HdBoard     43
# MetalSd     42
# Wd Sdng     32
# CemntBd     19
# Plywood     15
# BrkFace      9
# WdShing      7
# Stucco       3
# AsbShng      1
# BrkComm      1
# CBlock       1
# Name: Exterior1st, dtype: int64

# %%
df1['Exterior2nd'].unique()
# Out:
# array(['VinylSd', 'HdBoard', 'MetalSd', 'CmentBd', 'Wd Sdng', 'Plywood',
#        'Wd Shng', 'Brk Cmn', 'ImStucc', 'AsbShng', 'BrkFace', 'Stone',
#        'CBlock', 'Stucco'], dtype=object)

# %%
df1['Exterior2nd'].value_counts()
# Out:
# VinylSd    117
# MetalSd     41
# HdBoard     37
# Wd Sdng     32
# Plywood     24
# CmentBd     18
# Wd Shng      7
# BrkFace      5
# Stucco       3
# Brk Cmn      2
# ImStucc      2
# AsbShng      2
# Stone        1
# CBlock       1
# Name: Exterior2nd, dtype: int64

# %%
df1['MasVnrType'].unique()
# Out:
# array(['Stone', 'None', 'BrkFace', nan, 'BrkCmn'], dtype=object)

# %%
df1['MasVnrType'].value_counts()
# Out:
# None       168
# BrkFace     91
# Stone       30
# BrkCmn       2
# Name: MasVnrType, dtype: int64

# %%
df1['ExterQual'].unique()
# Out:
# array(['Gd', 'TA', 'Fa', 'Ex'], dtype=object)

# %%
df1['ExterQual'].value_counts()
# Out:
# TA    189
# Gd     91
# Ex      9
# Fa      3
# Name: ExterQual, dtype: int64

# %%
df1['ExterCond'].unique()
# Out:
# array(['TA', 'Gd', 'Fa', 'Ex'], dtype=object)

# %%
df1['ExterCond'].value_counts()
# Out:
# TA    260
# Gd     29
# Fa      2
# Ex      1
# Name: ExterCond, dtype: int64

# %%
df1['Foundation'].unique()
# Out:
# array(['PConc', 'CBlock', 'BrkTil', 'Slab', 'Wood', 'Stone'], dtype=object)

# %%
df1['Foundation'].value_counts()
# Out:
# PConc     134
# CBlock    118
# BrkTil     34
# Slab        3
# Wood        2
# Stone       1
# Name: Foundation, dtype: int64

# %%
df1['BsmtQual'].unique()
# Out:
# array(['Ex', 'Gd', 'TA', nan, 'Fa'], dtype=object)

# %%
df1['BsmtQual'].value_counts()
# Out:
# TA    132
# Gd    120
# Ex     27
# Fa      6
# Name: BsmtQual, dtype: int64

# %%
df1['BsmtCond'].value_counts()
# Out:
# TA    270
# Gd      9
# Fa      6
# Name: BsmtCond, dtype: int64

# %%
df1['BsmtExposure'].unique()
# Out:
# array(['Gd', 'Av', 'No', 'Mn', nan], dtype=object)

# %%
df1['BsmtExposure'].value_counts()
# Out:
# No    197
# Av     41
# Gd     26
# Mn     21
# Name: BsmtExposure, dtype: int64

# %%
df1['BsmtFinType1'].unique()
# Out:
# array(['GLQ', 'Unf', 'Rec', 'BLQ', 'ALQ', nan, 'LwQ'], dtype=object)

# %%
df1['BsmtFinType1'].value_counts()
# Out:
# GLQ    88
# Unf    85
# ALQ    46
# BLQ    27
# Rec    24
# LwQ    15
# Name: BsmtFinType1, dtype: int64

# %%
df1['BsmtFinSF1'].unique()
# Out:
# array([1249, 1036,    0,  275,  131,  547, 1400, 1518,  866,  457, 1159,
#         241,  625,  521,  450,  495,  624,  695,  384,  658,  540,  404,
#         833,   24, 1040,  814,  231,  593,  311,  104,  986,  410,  298,
#         425,  369,  904, 1234,  408, 1567,  648,  462,  381,  250,  659,
#         720,  273,  646,  213,  702,  196,  700,  111,  443,  631,  300,
#         871, 1218,  673,  180, 1213,  523,  816,  543,  156,  897,  428,
#        1150,  360, 1056, 1351, 1157,  319,  985,  731,  786,  716,  515,
#        1216,  580,  394,  534,  306,  188,  595,  840,  438,  297, 1039,
#         510, 1416, 1277,  656,  315,  663,  322,  550,  528,  152,  680,
#         420,  819, 1200,  492, 1274,  837,  763,  980,  400,  828, 1016,
#         570,  264,  732,  936,  604, 1767, 1261,  341,  116,  378,  317,
#         783,  348,   41,  883,  686,  612,  500,  697,  956, 1238,  906,
#         414,  565,  329,  403,  259,  662,  133,  588, 1237,  679,  442,
# ...

# %%
df1['BsmtFinSF1'].value_counts()
# Out:
# 0       92
# 298      2
# 565      2
# 936      2
# 384      2
#         ..
# 1351     1
# 1157     1
# 319      1
# 985      1
# 309      1
# Name: BsmtFinSF1, Length: 184, dtype: int64

# %%
df1['BsmtFinType2'].unique()
# Out:
# array(['Unf', 'GLQ', 'Rec', 'BLQ', 'LwQ', nan, 'ALQ'], dtype=object)

# %%
df1['BsmtFinType2'].value_counts()
# Out:
# Unf    254
# Rec     11
# BLQ      9
# LwQ      6
# ALQ      3
# GLQ      2
# Name: BsmtFinType2, dtype: int64

# %%
df1['BsmtFinSF2'].unique()
# Out:
# array([   0,  499,  374,  391,  174,  215,  169,  420,  712,  492,  273,
#         345,  354,  352,  119,   96, 1085,  668,  557,  105,  469,  279,
#         480,  539,  165,  713,  551,  465,  600,  506,  820,  491])

# %%
df1['BsmtFinSF2'].value_counts()
# Out:
# 0       261
# 499       1
# 820       1
# 506       1
# 600       1
# 465       1
# 551       1
# 713       1
# 165       1
# 539       1
# 480       1
# 279       1
# 469       1
# 105       1
# 557       1
# 668       1
# 1085      1
# 96        1
# 119       1
# 352       1
# 354       1
# 345       1
# 273       1
# 492       1
# 712       1
# 420       1
# 169       1
# 215       1
# 174       1
# 391       1
# 374       1
# 491       1
# Name: BsmtFinSF2, dtype: int64

# %%
df1['BsmtUnfSF'].unique()
# Out:
# array([ 673,  184, 1753,  429,  894,    0,  310,  338,  520,  193,  988,
#         413, 1935,  229,  208,  169,  241,  354,   26,  660,  519,  384,
#         218,  953,  728,  304, 1007,  343, 1836,  352,  768,  114,  399,
#         130,  544,  516,  484,  847,  811,  572,  459,  671,  680,  410,
#         464,  156,  732, 1264, 1078,  783, 1626,  210,  189,  638,  468,
#         995,  192,  975,  983,  833,  662,  652,  611, 1232,  350,  378,
#         707,  676, 1497,   84,  528,  301,  656, 1217, 1689,  261,  698,
#         918,  692,  319, 1048,  316,  504, 1284,  600,  932,  994,   83,
#        1584,  936,  808,  280,  539,  718,  595,  803,  540,  326,  173,
#         274,  115, 1368,  896,  333,  586,  246,  372,  736,  204,  200,
#         234,  797,  705,  264, 1580,  278, 1410,  207,  300,  952,  420,
#         840,  612,  396,   80,  536,  163, 1152,  977,  292,  336, 1422,
#         279,  901,  256,  105,  746,  110,  522,  100, 1498,  174,  556,
# ...

# %%
df1['BsmtUnfSF'].value_counts()
# Out:
# 0      21
# 384     4
# 768     3
# 698     3
# 378     2
#        ..
# 718     1
# 595     1
# 803     1
# 540     1
# 605     1
# Name: BsmtUnfSF, Length: 231, dtype: int64

# %%
df1['TotalBsmtSF'].unique()
# Out:
# array([1922, 1220, 1753,  704,  894,  630,  547, 1710, 1518, 1204,  520,
#        1024,  988, 1572, 1935,  861,  833,  864,  691, 1064,  650,  660,
#        1214,    0,  768,  876,  953, 1268,  708, 1007, 1176, 1860, 1392,
#         384,  928,  723,  855,  789, 1470,  847, 1221,  870,  884, 1040,
#         680, 1314, 1698,  984, 1567,  732, 1264,  648, 1078,  783,  816,
#        1626,  462,  780,  952,  848, 1358,  546, 1114, 1208, 1516, 1683,
#         819, 1105, 1041, 1482, 1256, 1568, 1051,  707, 1728, 1297,  528,
#         824,  656, 2033,  727, 1689,  923,  698,  918, 1216, 1476, 1466,
#        1284,  600,  932,  994, 1056, 1434, 1584,  936,  808, 1437,  858,
#         718, 1580,  803,  540, 1057,  959,  990, 1368,  896,  913,  980,
#        1763,  736, 1060,  973,  672,  854, 1836, 1364,  264,  788, 1650,
#        1410, 1484,  956,  840,  612, 1059,  728,  713, 1680, 1598,  972,
#         756, 1422, 1003, 1479,  901, 1530,  942,  746,  955, 1090,  912,
# ...

# %%
df1['TotalBsmtSF'].value_counts()
# Out:
# 864     7
# 0       7
# 672     4
# 848     4
# 768     4
#        ..
# 600     1
# 932     1
# 1434    1
# 1584    1
# 1060    1
# Name: TotalBsmtSF, Length: 224, dtype: int64

# %%
df1['Heating'].unique()
# Out:
# array(['GasA', 'Grav', 'GasW', 'OthW'], dtype=object)

# %%
df1['Heating'].value_counts()
# Out:
# GasA    285
# GasW      4
# Grav      2
# OthW      1
# Name: Heating, dtype: int64

# %%
df1['HeatingQC'].unique()
# Out:
# array(['Ex', 'Gd', 'Fa', 'TA'], dtype=object)

# %%
df1['HeatingQC'].value_counts()
# Out:
# Ex    156
# TA     76
# Gd     49
# Fa     11
# Name: HeatingQC, dtype: int64

# %%
df1['CentralAir'].unique()
# Out:
# array(['Y', 'N'], dtype=object)

# %%
df1['CentralAir'].value_counts()
# Out:
# Y    275
# N     17
# Name: CentralAir, dtype: int64

# %%
df1['Electrical'].unique()
# Out:
# array(['SBrkr', 'FuseA', 'FuseP', nan, 'FuseF'], dtype=object)

# %%
df1['Electrical'].value_counts()
# Out:
# SBrkr    264
# FuseA     20
# FuseF      6
# FuseP      1
# Name: Electrical, dtype: int64

# %%
df1['1stFlrSF'].unique()
# Out:
# array([1922, 1360, 1788,  860,  894,  630, 1072, 1710, 1644, 1204,  520,
#        1344,  988, 1572, 1973,  961,  833,  864,  713, 1064,  832, 1285,
#        1214,  372,  790,  923,  953, 1268,  708, 1077, 1318, 1200, 1836,
#        1392,  792,  774,  936,  735,  855,  789, 1470,  847, 1221,  914,
#         959, 1040,  764, 1314, 1698,  984, 1567,  772, 1277,  960, 1128,
#         807,  816, 1634,  526, 1088, 1211,  848, 1358,  546, 1114, 1621,
#        1516, 2129, 1053, 1105, 1125,  980, 1482, 1269, 1689, 1159,  707,
#        1136, 1728, 1297, 1094, 1687,  968, 2053,  829,  698,  918, 1118,
#        1216, 1484,  812, 1466, 1284,  747,  932,  754, 1028, 1056, 1518,
#        1776,  962, 1161, 1437,  858, 1576, 1079,  803,  889, 1057,  990,
#        1048, 1368, 1298,  896, 1779,  944,  736, 1060,  979,  672, 1096,
#        1364,  616, 1580,  804, 1690, 1426, 1600,  956, 1022,  840,  882,
#         612, 1068,  728,  811, 1724, 1636,  972,  756, 1422, 1003, 1494,
# ...

# %%
df1['1stFlrSF'].value_counts()
# Out:
# 864     6
# 630     4
# 840     4
# 698     4
# 990     4
#        ..
# 747     1
# 932     1
# 754     1
# 1028    1
# 1563    1
# Name: 1stFlrSF, Length: 238, dtype: int64

# %%
df1['2ndFlrSF'].unique()
# Out:
# array([   0,  704, 1039,  406,  739,  703,  650,  720,  694,  708,  584,
#         656,  785,  672,  660,  586, 1160,  886,  408,  620,  351, 1067,
#         445,  702,  462,  780,  546,  743,  795, 1169, 1276,  707,  768,
#         761,  998, 1185,  727,  711,  698,  912,  670, 1362,  885,  640,
#         776,  631,  830,  808,  858,  978,  874,  557,  551,  712, 1216,
#         896,  510,  734,  716,  871,  714,  895,  688, 1589, 1519, 1128,
#         752,  534,  828,  612,  728,  741,  971,  756,  110, 1230,  804,
#        1096,  630,  448,  566,  860,  817,  779,  605, 1296,  504,  838,
#         932, 1044,  875, 1215,  884,  933,  430,  750,  560,  738, 1479,
#         252, 1281,  580,  840,  956,  600,  836,  520, 1104,  784,  467,
#         468,  994, 1237])

# %%
df1['2ndFlrSF'].value_counts()
# Out:
# 0       166
# 896       2
# 546       2
# 780       2
# 858       2
#        ...
# 1362      1
# 670       1
# 912       1
# 698       1
# 1237      1
# Name: 2ndFlrSF, Length: 113, dtype: int64

# %%
df1['LowQualFinSF'].unique()
# Out:
# array([  0, 397, 479, 205])

# %%
df1['LowQualFinSF'].value_counts()
# Out:
# 0      289
# 397      1
# 479      1
# 205      1
# Name: LowQualFinSF, dtype: int64

# %%
df1['GrLivArea'].unique()
# Out:
# array([1922, 1360, 1788, 1564, 1933,  630, 1072, 1710, 1644, 1204,  520,
#        1344,  988, 1572, 1973, 1367,  833,  864, 1452, 1767, 1482, 1285,
#        1214, 1092,  790,  923, 1647, 1268, 1416, 1077, 1902, 1200, 1836,
#        1392,  792, 1430, 1721, 1302, 1395, 1441,  789, 2630, 1733, 1221,
#         914, 1040,  764, 1314, 1698, 1604, 1567, 1123, 2344,  960, 1573,
#        1509,  816, 1634, 1868, 1211,  848, 1358, 1114, 1621,  894, 1516,
#        2872, 1848, 2274, 1125, 2256, 2262, 1269, 1689, 1159, 1414, 1904,
#        1728, 1297, 1855, 3082,  968, 3238, 1556, 1664, 1396,  918, 2030,
#        1216, 1484, 2828, 2169,  747,  932, 1394, 1804, 1056, 2149, 1776,
#        1792, 1969, 1437, 1716, 2554, 1953, 1440, 1057, 1671,  990, 1048,
#        1368, 2514, 1558, 1714, 1779,  944, 1060, 1850, 1386, 1991, 1364,
#        1304, 2466,  804, 3279, 2945, 1600, 2084, 1774, 1374,  882, 1668,
#        1224, 1068, 1456,  858,  698, 1552, 1724, 3086,  972, 1512, 1422,
# ...

# %%
df1['GrLivArea'].value_counts()
# Out:
# 864     6
# 990     4
# 1360    3
# 1040    3
# 988     3
#        ..
# 2149    1
# 1776    1
# 1969    1
# 1437    1
# 1563    1
# Name: GrLivArea, Length: 246, dtype: int64

# %%
df1['BsmtFullBath'].unique()
# Out:
# array([1, 0, 2])

# %%
df1['BsmtFullBath'].value_counts()
# Out:
# 0    170
# 1    120
# 2      2
# Name: BsmtFullBath, dtype: int64

# %%
df1['BsmtHalfBath'].unique()
# Out:
# array([0, 1])

# %%
df1['BsmtHalfBath'].value_counts()
# Out:
# 0    273
# 1     19
# Name: BsmtHalfBath, dtype: int64

# %%
df1['FullBath'].unique()
# Out:
# array([2, 1, 0, 3])

# %%
df1['FullBath'].value_counts()
# Out:
# 2    158
# 1    126
# 3      6
# 0      2
# Name: FullBath, dtype: int64

# %%
df1['HalfBath'].unique()
# Out:
# array([0, 1, 2])

# %%
df1['HalfBath'].value_counts()
# Out:
# 0    189
# 1    101
# 2      2
# Name: HalfBath, dtype: int64

# %%
df1['BedroomAbvGr'].unique()
# Out:
# array([3, 1, 4, 2, 0, 5, 6])

# %%
df1['BedroomAbvGr'].value_counts()
# Out:
# 3    164
# 2     77
# 4     33
# 1     11
# 5      3
# 0      2
# 6      2
# Name: BedroomAbvGr, dtype: int64

# %%
df1['KitchenAbvGr'].unique()
# Out:
# array([1, 2, 3])

# %%
df1['KitchenAbvGr'].value_counts()
# Out:
# 1    278
# 2     13
# 3      1
# Name: KitchenAbvGr, dtype: int64

# %%
df1['KitchenQual'].unique()
# Out:
# array(['Gd', 'Ex', 'Fa', 'TA'], dtype=object)

# %%
df1['KitchenQual'].value_counts()
# Out:
# TA    157
# Gd    108
# Ex     18
# Fa      9
# Name: KitchenQual, dtype: int64

# %%
df1['TotRmsAbvGrd'].unique()
# Out:
# array([ 8,  4,  7,  9,  3,  5,  6, 12, 10, 11])

# %%
df1['TotRmsAbvGrd'].value_counts()
# Out:
# 6     77
# 7     61
# 5     58
# 8     39
# 4     25
# 9     10
# 3      6
# 10     6
# 12     5
# 11     5
# Name: TotRmsAbvGrd, dtype: int64

# %%
df1['Functional'].unique()
# Out:
# array(['Typ', 'Min1', 'Mod', 'Min2', 'Maj1', 'Maj2'], dtype=object)

# %%
df1['Functional'].value_counts()
# Out:
# Typ     275
# Min1      6
# Min2      4
# Mod       3
# Maj1      3
# Maj2      1
# Name: Functional, dtype: int64

# %%
df1['Fireplaces'].unique()
# Out:
# array([1, 0, 2])

# %%
df1['Fireplaces'].value_counts()
# Out:
# 0    139
# 1    132
# 2     21
# Name: Fireplaces, dtype: int64

# %%
df1['GarageType'].unique()
# Out:
# array(['Attchd', 'BuiltIn', nan, 'Basment', 'Detchd', '2Types', 'CarPort'],
#       dtype=object)

# %%
df1['GarageType'].value_counts()
# Out:
# Attchd     179
# Detchd      73
# BuiltIn     18
# Basment      3
# 2Types       1
# CarPort      1
# Name: GarageType, dtype: int64

# %%
df1['GarageYrBlt'].unique()
# Out:
# array([2005., 1984., 2001., 1941., 2007.,   nan, 1989., 1998., 1920.,
#        1970., 1954., 1963., 2006., 1978., 1964., 1999., 1987., 1930.,
#        1977., 1967., 1925., 1968., 1922., 2003., 2004., 1957., 1924.,
#        2000., 1994., 1972., 1948., 1959., 1965., 2008., 1979., 1926.,
#        1996., 1973., 1976., 1992., 1958., 1960., 2002., 1950., 1928.,
#        1980., 1953., 1962., 1951., 1940., 1990., 1988., 1955., 1956.,
#        1949., 1931., 2009., 1975., 1997., 1966., 1993., 1939., 1969.,
#        1971., 1916., 1974., 1982., 1991., 2010., 1938., 1995., 1985.])

# %%
df1['GarageYrBlt'].value_counts()
# Out:
# 2004.0    17
# 2005.0    14
# 2003.0    13
# 1977.0    11
# 1976.0     9
# 2007.0     9
# 2000.0     9
# 2008.0     8
# 1968.0     8
# 2006.0     7
# 1999.0     7
# 1996.0     7
# 1998.0     6
# 1950.0     6
# 1970.0     6
# 1967.0     5
# 1972.0     5
# 1964.0     5
# 1978.0     5
# 1954.0     5
# 1984.0     4
# 1958.0     4
# 1965.0     4
# 1973.0     4
# 1979.0     4
# 1956.0     3
# 1962.0     3
# 1953.0     3
# 1980.0     3
# 2009.0     3
# 1966.0     3
# 1960.0     3
# 1939.0     3
# 1992.0     3
# 2002.0     3
# 1963.0     3
# 1959.0     3
# 1994.0     3
# 1987.0     3
# 1941.0     3
# 1925.0     3
# 1926.0     2
# 1990.0     2
# 1993.0     2
# 1997.0     2
# 1930.0     2
# 1991.0     2
# 1988.0     2
# 1940.0     2
# 1922.0     2
# 1920.0     2
# 1957.0     2
# 1928.0     2
# 1989.0     2
# 1948.0     2
# 2001.0     2
# 1916.0     1
# 1938.0     1
# 2010.0     1
# 1982.0     1
# 1995.0     1
# 1974.0     1
# 1949.0     1
# 1971.0     1
# 1969.0     1
# 1975.0     1
# ...

# %%
df1['GarageFinish'].unique()
# Out:
# array(['Fin', 'RFn', 'Unf', nan], dtype=object)

# %%
df1['GarageFinish'].value_counts()
# Out:
# Unf    118
# RFn     83
# Fin     74
# Name: GarageFinish, dtype: int64

# %%
df1['GarageCars'].unique()
# Out:
# array([3, 2, 1, 0, 4])

# %%
df1['GarageCars'].value_counts()
# Out:
# 2    159
# 1     81
# 3     34
# 0     17
# 4      1
# Name: GarageCars, dtype: int64

# %%
df1['GarageArea'].unique()
# Out:
# array([ 676,  565,  522,  234,  668,    0,  525,  866,  569,  412,  240,
#         484,  520,  995,  895,  384,  624,  506,  504,  324,  528,  318,
#         160,  264,  460,  244,  776,  210,  539,  555,  458,  400,  471,
#         497,  440,  250,  696,  433,  576,  560,  286,  626,  768,  660,
#         714,  200,  889,  364,  360,  393,  516,  297,  322,  420,  450,
#         472,  541,  370,  480,  352,  554,  749,  430,  857,  336,  403,
#         498,  512,  672,  216,  666,  441,  954,  551,  402,  392, 1052,
#         288,  647,  306,  442,  670,  888,  451,  534,  490,  704,  501,
#         246,  474,  693,  496,  276,  454,  270,  467,  572,  432,  862,
#         610,  841,  641,  319,  618,  468,  338,  308,  500,  410,  684,
#         434,  588,  248,  397,  386,  592,  902,  726,  870,  772,  431,
#         343,  299,  600,  312,  632,  300,  968,  936,  292,  380,  225,
#         543,  577,  860,  540,  874,  765,  564,  280,  304,  578,  389,
# ...

# %%
df1['GarageArea'].value_counts()
# Out:
# 0       17
# 484     12
# 264      9
# 576      8
# 240      7
#         ..
# 306      1
# 647      1
# 324      1
# 1052     1
# 758      1
# Name: GarageArea, Length: 166, dtype: int64

# %%
df1['GarageQual'].unique()
# Out:
# array(['TA', nan, 'Fa', 'Gd', 'Po', 'Ex'], dtype=object)

# %%
df1['GarageQual'].value_counts()
# Out:
# TA    261
# Fa      9
# Gd      3
# Po      1
# Ex      1
# Name: GarageQual, dtype: int64

# %%
df1['GarageCond'].unique()
# Out:
# array(['TA', nan, 'Fa', 'Po', 'Ex', 'Gd'], dtype=object)

# %%
df1['GarageCond'].value_counts()
# Out:
# TA    265
# Fa      7
# Po      1
# Ex      1
# Gd      1
# Name: GarageCond, dtype: int64

# %%
df1['PavedDrive'].unique()
# Out:
# array(['Y', 'N', 'P'], dtype=object)

# %%
df1['PavedDrive'].value_counts()
# Out:
# Y    269
# N     16
# P      7
# Name: PavedDrive, dtype: int64

# %%
df1['WoodDeckSF'].unique()
# Out:
# array([178,  63, 202,   0, 100,  80,  49, 316, 315, 441, 138, 362, 120,
#        300, 185, 294,  28, 140, 172, 327, 264, 220,  88, 106, 448, 192,
#        238, 108, 296, 224, 168, 146, 150, 466, 113, 136, 283, 125, 216,
#        132,  32, 228, 406, 335, 141, 159, 503, 288,  90, 144,  36, 209,
#        122, 728,  12,  68, 400, 147,  40, 295, 519,  74, 105, 149, 208,
#         97, 154,  58, 160, 206,  30, 270, 342, 115, 314, 320, 280, 276,
#        306, 135, 139, 156, 126, 145, 195, 536,  72])

# %%
df1['WoodDeckSF'].value_counts()
# Out:
# 0      158
# 100     10
# 192     10
# 168      8
# 120      6
#       ...
# 159      1
# 503      1
# 288      1
# 90       1
# 72       1
# Name: WoodDeckSF, Length: 87, dtype: int64

# %%
df1['OpenPorchSF'].unique()
# Out:
# array([ 51,   0, 151,  18,  28, 102, 247, 263,  45, 130,  34,  35, 111,
#        141,  40,  98, 169, 100,  41,  33,  87, 116,  66,  48, 113,  62,
#         64,  68,  32,  75,  44, 101,  96,  63,  30, 118,  54,  20,  59,
#         86,  56, 224, 125,  25, 144,  60,  43,  21,  84, 231,  65,  52,
#         38,  27,  80, 418,  90, 110, 185,  36,  24, 214,  50, 258, 234,
#        200, 208, 128,  49, 285, 174,  16,  70,  72, 112, 119, 304,  61,
#        210,  42,  55,  29,  69,  85,  12,  58, 198, 136,  99,  95, 252,
#        287])

# %%
df1['OpenPorchSF'].value_counts()
# Out:
# 0      125
# 45       6
# 36       5
# 30       5
# 35       5
#       ...
# 418      1
# 110      1
# 185      1
# 214      1
# 287      1
# Name: OpenPorchSF, Length: 92, dtype: int64

# %%
df1['EnclosedPorch'].unique()
# Out:
# array([  0,  87, 112,  48, 120, 252, 140, 168,  32, 214, 143, 190,  77,
#        156, 102,  19, 154,  37, 205, 198,  84, 150, 144, 100, 114, 330,
#         20, 164,  94, 184, 240, 160, 226,  80, 183,  36])

# %%
df1['EnclosedPorch'].value_counts()
# Out:
# 0      253
# 112      2
# 144      2
# 120      2
# 32       2
# 94       1
# 100      1
# 114      1
# 330      1
# 20       1
# 164      1
# 240      1
# 184      1
# 84       1
# 160      1
# 226      1
# 80       1
# 183      1
# 150      1
# 205      1
# 198      1
# 87       1
# 37       1
# 154      1
# 19       1
# 102      1
# 156      1
# 77       1
# 190      1
# 143      1
# 214      1
# 168      1
# 140      1
# 252      1
# 48       1
# 36       1
# Name: EnclosedPorch, dtype: int64

# %%
df1['3SsnPorch'].unique()
# Out:
# array([  0, 320, 407])

# %%
df1['3SsnPorch'].value_counts()
# Out:
# 0      290
# 320      1
# 407      1
# Name: 3SsnPorch, dtype: int64

# %%
df1['ScreenPorch'].unique()
# Out:
# array([  0, 396, 263, 119, 192, 120, 152, 233, 220, 144, 259, 198, 276,
#        180, 312, 210, 170, 374, 147,  90, 234])

# %%
df1['ScreenPorch'].value_counts()
# Out:
# 0      271
# 120      2
# 198      1
# 90       1
# 147      1
# 374      1
# 170      1
# 210      1
# 312      1
# 180      1
# 276      1
# 259      1
# 396      1
# 144      1
# 220      1
# 233      1
# 152      1
# 192      1
# 119      1
# 263      1
# 234      1
# Name: ScreenPorch, dtype: int64

# %%
df1['PoolArea'].unique()
# Out:
# array([0])

# %%
df1['PoolArea'].value_counts()
# Out:
# 0    292
# Name: PoolArea, dtype: int64

# %%
df1['MiscVal'].unique()
# Out:
# array([   0, 3500,  400,  600,  500,  480,  700,  450])

# %%
df1['MiscVal'].value_counts()
# Out:
# 0       282
# 450       3
# 700       2
# 3500      1
# 400       1
# 600       1
# 500       1
# 480       1
# Name: MiscVal, dtype: int64

# %%
df1['MoSold'].unique()
# Out:
# array([ 7,  8,  6,  1, 12,  5,  2,  4,  3, 10, 11,  9])

# %%
df1['MoSold'].value_counts()
# Out:
# 6     50
# 7     47
# 5     38
# 4     28
# 8     27
# 10    23
# 3     19
# 2     15
# 1     14
# 12    13
# 11    12
# 9      6
# Name: MoSold, dtype: int64

# %%
df1['YrSold'].unique()
# Out:
# array([2007, 2009, 2008, 2006, 2010])

# %%
df1['YrSold'].value_counts()
# Out:
# 2009    78
# 2007    65
# 2006    60
# 2008    56
# 2010    33
# Name: YrSold, dtype: int64

# %%
df1['SaleType'].unique()
# Out:
# array(['WD', 'COD', 'New', 'ConLD', 'CWD', 'ConLw'], dtype=object)

# %%
df1['SaleType'].value_counts()
# Out:
# WD       268
# New       16
# COD        5
# ConLD      1
# CWD        1
# ConLw      1
# Name: SaleType, dtype: int64

# %%
df1['SaleCondition'].unique()
# Out:
# array(['Normal', 'Abnorml', 'Partial', 'Family'], dtype=object)

# %%
df1['SaleCondition'].value_counts()
# Out:
# Normal     253
# Abnorml     20
# Partial     17
# Family       2
# Name: SaleCondition, dtype: int64

# %% [markdown]
# ## FILLING IN THE MISSING VALUES

# %%
from sklearn.impute import SimpleImputer

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 292 entries, 0 to 291
# Data columns (total 75 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             292 non-null    int64
#  1   MSSubClass     292 non-null    int64
#  2   MSZoning       292 non-null    object
#  3   LotFrontage    247 non-null    float64
#  4   LotArea        292 non-null    int64
#  5   Street         292 non-null    object
#  6   LotShape       292 non-null    object
#  7   LandContour    292 non-null    object
#  8   Utilities      292 non-null    object
#  9   LotConfig      292 non-null    object
#  10  LandSlope      292 non-null    object
#  11  Neighborhood   292 non-null    object
#  12  Condition1     292 non-null    object
#  13  Condition2     292 non-null    object
#  14  BldgType       292 non-null    object
#  15  HouseStyle     292 non-null    object
#  16  OverallQual    292 non-null    int64
# ...

# %%
imp=SimpleImputer(missing_values=np.NaN,strategy='most_frequent')

# %%
imp1=SimpleImputer(missing_values=np.NaN,strategy='mean')

# %%
df1['GarageCond']=imp.fit_transform(df1['GarageCond'].values.reshape(-1,1))

# %%
df1['GarageQual']=imp.fit_transform(df1['GarageQual'].values.reshape(-1,1))

# %%
df1['GarageFinish']=imp.fit_transform(df1['GarageFinish'].values.reshape(-1,1))

# %%
df1['GarageYrBlt']=imp1.fit_transform(df1['GarageYrBlt'].values.reshape(-1,1))

# %%
df1['LotFrontage']=imp1.fit_transform(df1['LotFrontage'].values.reshape(-1,1))

# %%
df1['GarageType']=imp.fit_transform(df1['GarageType'].values.reshape(-1,1))

# %%
df1['MasVnrType']=imp.fit_transform(df1['MasVnrType'].values.reshape(-1,1))

# %%
df1['MasVnrArea']=imp1.fit_transform(df1['MasVnrArea'].values.reshape(-1,1))

# %%
df1['BsmtQual']=imp.fit_transform(df1['BsmtQual'].values.reshape(-1,1))

# %%
df1['BsmtCond']=imp.fit_transform(df1['BsmtCond'].values.reshape(-1,1))

# %%
df1['BsmtExposure']=imp.fit_transform(df1['BsmtExposure'].values.reshape(-1,1))

# %%
df1['BsmtFinType1']=imp.fit_transform(df1['BsmtFinType1'].values.reshape(-1,1))

# %%
df1['BsmtFinType2']=imp.fit_transform(df1['BsmtFinType2'].values.reshape(-1,1))

# %%
df1.isnull().sum()
# Out:
# Id               0
# MSSubClass       0
# MSZoning         0
# LotFrontage      0
# LotArea          0
#                 ..
# MiscVal          0
# MoSold           0
# YrSold           0
# SaleType         0
# SaleCondition    0
# Length: 75, dtype: int64

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 292 entries, 0 to 291
# Data columns (total 75 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             292 non-null    int64
#  1   MSSubClass     292 non-null    int64
#  2   MSZoning       292 non-null    object
#  3   LotFrontage    292 non-null    float64
#  4   LotArea        292 non-null    int64
#  5   Street         292 non-null    object
#  6   LotShape       292 non-null    object
#  7   LandContour    292 non-null    object
#  8   Utilities      292 non-null    object
#  9   LotConfig      292 non-null    object
#  10  LandSlope      292 non-null    object
#  11  Neighborhood   292 non-null    object
#  12  Condition1     292 non-null    object
#  13  Condition2     292 non-null    object
#  14  BldgType       292 non-null    object
#  15  HouseStyle     292 non-null    object
#  16  OverallQual    292 non-null    int64
# ...

# %% [markdown]
# ## FIRST 5 ROWS CHECK

# %%
df1.head()
# Out:
#      Id  MSSubClass MSZoning  LotFrontage  LotArea Street LotShape  \
# 0   337          20       RL    86.000000    14157   Pave      IR1
# 1  1018         120       RL    66.425101     5814   Pave      IR1
# 2   929          20       RL    66.425101    11838   Pave      Reg
# 3  1148          70       RL    75.000000    12000   Pave      Reg
# 4  1227          60       RL    86.000000    14598   Pave      IR1
#
#   LandContour Utilities LotConfig  ... OpenPorchSF EnclosedPorch 3SsnPorch  \
# 0         HLS    AllPub    Corner  ...          51             0         0
# 1         Lvl    AllPub   CulDSac  ...           0             0         0
# 2         Lvl    AllPub    Inside  ...         151             0         0
# 3         Bnk    AllPub    Inside  ...           0             0         0
# 4         Lvl    AllPub   CulDSac  ...          18             0         0
#
#   ScreenPorch PoolArea MiscVal  MoSold  YrSold  SaleType  SaleCondition
# ...

# %% [markdown]
# ## LAST 5 ROWS CHECK

# %%
df1.tail()
# Out:
#        Id  MSSubClass MSZoning  LotFrontage  LotArea Street LotShape  \
# 287    83          20       RL    78.000000    10206   Pave      Reg
# 288  1048          20       RL    57.000000     9245   Pave      IR2
# 289    17          20       RL    66.425101    11241   Pave      IR1
# 290   523          50       RM    50.000000     5000   Pave      Reg
# 291  1379         160       RM    21.000000     1953   Pave      Reg
#
#     LandContour Utilities LotConfig  ... OpenPorchSF EnclosedPorch 3SsnPorch  \
# 287         Lvl    AllPub    Inside  ...          99             0         0
# 288         Lvl    AllPub    Inside  ...           0             0         0
# 289         Lvl    AllPub   CulDSac  ...           0             0         0
# 290         Lvl    AllPub    Corner  ...          24            36         0
# 291         Lvl    AllPub    Inside  ...           0             0         0
#
#     ScreenPorch PoolArea MiscVal  MoSold  YrSold  SaleType  SaleCondition
# ...

# %% [markdown]
# ## SAMPLE ROW CHECK

# %%
df1.sample()
# Out:
#      Id  MSSubClass MSZoning  LotFrontage  LotArea Street LotShape  \
# 285  72          20       RL         69.0     7599   Pave      Reg
#
#     LandContour Utilities LotConfig  ... OpenPorchSF EnclosedPorch 3SsnPorch  \
# 285         Lvl    AllPub    Corner  ...           0             0         0
#
#     ScreenPorch PoolArea MiscVal  MoSold  YrSold  SaleType  SaleCondition
# 285           0        0       0       6    2007        WD         Normal
#
# [1 rows x 75 columns]

# %% [markdown]
# ## NON GRAPHICAL UNIVARIATE ANALYSIS

# %%
df1.describe()
# Out:
#                 Id  MSSubClass  LotFrontage        LotArea  OverallQual  \
# count   292.000000  292.000000   292.000000     292.000000   292.000000
# mean    755.955479   57.414384    66.425101   10645.143836     6.078767
# std     442.565228   43.780649    19.975962   13330.669795     1.356147
# min       6.000000   20.000000    21.000000    1526.000000     3.000000
# 25%     377.750000   20.000000    57.750000    7200.000000     5.000000
# 50%     778.000000   50.000000    66.425101    9200.000000     6.000000
# 75%    1152.250000   70.000000    76.000000   11658.750000     7.000000
# max    1456.000000  190.000000   150.000000  215245.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  ...  \
# count   292.000000   292.000000    292.000000   292.000000   292.000000  ...
# mean      5.493151  1972.616438   1985.294521   109.171821   439.294521  ...
# std       1.063267    30.447016     20.105792   174.729023   429.559675  ...
# ...

# %% [markdown]
# ## ENCODING THE DATA SET

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le=LabelEncoder()

# %%
df1['SaleCondition']=le.fit_transform(df1['SaleCondition'])

# %%
df1['SaleType']=le.fit_transform(df1['SaleType'])

# %%
df1['PavedDrive']=le.fit_transform(df1['PavedDrive'])

# %%
df1['GarageCond']=le.fit_transform(df1['GarageCond'])

# %%
df1['GarageQual']=le.fit_transform(df1['GarageQual'])

# %%
df1['GarageFinish']=le.fit_transform(df1['GarageFinish'])

# %%
df1['Functional']=le.fit_transform(df1['Functional'])

# %%
df1['MSZoning']=le.fit_transform(df1['MSZoning'])

# %%
df1['GarageType']=le.fit_transform(df1['GarageType'])

# %%
df1['KitchenQual']=le.fit_transform(df1['KitchenQual'])

# %%
df1['Street']=le.fit_transform(df1['Street'])

# %%
df1['LotShape']=le.fit_transform(df1['LotShape'])

# %%
df1['LandContour']=le.fit_transform(df1['LandContour'])

# %%
df1['Utilities']=le.fit_transform(df1['Utilities'])

# %%
df1['LotConfig']=le.fit_transform(df1['LotConfig'])

# %%
df1['LandSlope']=le.fit_transform(df1['LandSlope'])

# %%
df1['Neighborhood']=le.fit_transform(df1['Neighborhood'])

# %%
df1['Condition1']=le.fit_transform(df1['Condition1'])

# %%
df1['Condition2']=le.fit_transform(df1['Condition2'])

# %%
df1['BldgType']=le.fit_transform(df1['BldgType'])

# %%
df1['HouseStyle']=le.fit_transform(df1['HouseStyle'])

# %%
df1['RoofStyle']=le.fit_transform(df1['RoofStyle'])

# %%
df1['Exterior1st']=le.fit_transform(df1['Exterior1st'])

# %%
df1['RoofMatl']=le.fit_transform(df1['RoofMatl'])

# %%
df1['Exterior2nd']=le.fit_transform(df1['Exterior2nd'])

# %%
df1['MasVnrType']=le.fit_transform(df1['MasVnrType'])

# %%
df1['ExterQual']=le.fit_transform(df1['ExterQual'])

# %%
df1['Foundation']=le.fit_transform(df1['Foundation'])

# %%
df1['Heating']=le.fit_transform(df1['Heating'])

# %%
df1['BsmtQual']=le.fit_transform(df1['BsmtQual'])

# %%
df1['BsmtCond']=le.fit_transform(df1['BsmtCond'])

# %%
df1['BsmtExposure']=le.fit_transform(df1['BsmtExposure'])

# %%
df1['BsmtFinType1']=le.fit_transform(df1['BsmtFinType1'])

# %%
df1['BsmtFinType2']=le.fit_transform(df1['BsmtFinType2'])

# %%
df1['ExterCond']=le.fit_transform(df1['ExterCond'])

# %%
df1['HeatingQC']=le.fit_transform(df1['HeatingQC'])

# %%
df1['Electrical']=le.fit_transform(df1['Electrical'])

# %%
df1['CentralAir']=le.fit_transform(df1['CentralAir'])

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 292 entries, 0 to 291
# Data columns (total 75 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             292 non-null    int64
#  1   MSSubClass     292 non-null    int64
#  2   MSZoning       292 non-null    int64
#  3   LotFrontage    292 non-null    float64
#  4   LotArea        292 non-null    int64
#  5   Street         292 non-null    int64
#  6   LotShape       292 non-null    int64
#  7   LandContour    292 non-null    int64
#  8   Utilities      292 non-null    int64
#  9   LotConfig      292 non-null    int64
#  10  LandSlope      292 non-null    int64
#  11  Neighborhood   292 non-null    int64
#  12  Condition1     292 non-null    int64
#  13  Condition2     292 non-null    int64
#  14  BldgType       292 non-null    int64
#  15  HouseStyle     292 non-null    int64
#  16  OverallQual    292 non-null    int64
#  17  OverallCond    292 non-null    int64
# ...

# %% [markdown]
# ## ALL CATAGORICAL DATA HAS BEEN ENCODED

# %% [markdown]
# ## DELETING UTILITIES AND ID  COLUMN AS THE DATA IS IDENTICAL AND SERIAL

# %%
df2=df1.drop(columns=['Id','Utilities'],axis=1)

# %% [markdown]
# ## CORRELATION

# %%
df2.corr()
# Out:
#                MSSubClass  MSZoning  LotFrontage   LotArea    Street  \
# MSSubClass       1.000000  0.266517    -0.454786 -0.186654  0.004588
# MSZoning         0.266517  1.000000    -0.335754 -0.117968 -0.063162
# LotFrontage     -0.454786 -0.335754     1.000000  0.370091 -0.056531
# LotArea         -0.186654 -0.117968     0.370091  1.000000 -0.069626
# Street           0.004588 -0.063162    -0.056531 -0.069626  1.000000
# ...                   ...       ...          ...       ...       ...
# MiscVal          0.137542  0.090554     0.031567 -0.020398  0.010465
# MoSold          -0.004079  0.074308    -0.045333 -0.034709  0.036965
# YrSold           0.044441 -0.072716     0.059745  0.041735 -0.040272
# SaleType        -0.105307  0.123993     0.034876  0.037096 -0.019125
# SaleCondition   -0.010155  0.005290     0.037168  0.030689 -0.012345
#
#                LotShape  LandContour  LotConfig  LandSlope  Neighborhood  ...  \
# ...

# %%
plt.figure(figsize=(40,30))
sns.heatmap(df2.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## OUTLIERS CHECK - VISUAL

# %%
sns.boxplot(df2['MSSubClass'])
# Out:
# <AxesSubplot:xlabel='MSSubClass'>

# %%
sns.boxplot(df2['SaleCondition'])
# Out:
# <AxesSubplot:xlabel='SaleCondition'>

# %%
sns.boxplot(df2['SaleType'])
# Out:
# <AxesSubplot:xlabel='SaleType'>

# %%
sns.boxplot(df2['YrSold'])
# Out:
# <AxesSubplot:xlabel='YrSold'>

# %%
sns.boxplot(df2['MoSold'])
# Out:
# <AxesSubplot:xlabel='MoSold'>

# %%
sns.boxplot(df2['MiscVal'])
# Out:
# <AxesSubplot:xlabel='MiscVal'>

# %%
sns.boxplot(df2['PoolArea'])
# Out:
# <AxesSubplot:xlabel='PoolArea'>

# %%
sns.boxplot(df2['ScreenPorch'])
# Out:
# <AxesSubplot:xlabel='ScreenPorch'>

# %%
sns.boxplot(df2['3SsnPorch'])
# Out:
# <AxesSubplot:xlabel='3SsnPorch'>

# %%
sns.boxplot(df2['EnclosedPorch'])
# Out:
# <AxesSubplot:xlabel='EnclosedPorch'>

# %%
sns.boxplot(df2['OpenPorchSF'])
# Out:
# <AxesSubplot:xlabel='OpenPorchSF'>

# %%
sns.boxplot(df2['WoodDeckSF'])
# Out:
# <AxesSubplot:xlabel='WoodDeckSF'>

# %%
sns.boxplot(df2['PavedDrive'])
# Out:
# <AxesSubplot:xlabel='PavedDrive'>

# %%
sns.boxplot(df2['GarageCond'])
# Out:
# <AxesSubplot:xlabel='GarageCond'>

# %%
sns.boxplot(df2['GarageType'])
# Out:
# <AxesSubplot:xlabel='GarageType'>

# %%
sns.boxplot(df2['GarageQual'])
# Out:
# <AxesSubplot:xlabel='GarageQual'>

# %%
sns.boxplot(df2['GarageArea'])
# Out:
# <AxesSubplot:xlabel='GarageArea'>

# %%
sns.boxplot(df2['Fireplaces'])
# Out:
# <AxesSubplot:xlabel='Fireplaces'>

# %%
sns.boxplot(df2['GarageCars'])
# Out:
# <AxesSubplot:xlabel='GarageCars'>

# %%
sns.boxplot(df2['Functional'])
# Out:
# <AxesSubplot:xlabel='Functional'>

# %%
sns.boxplot(df2['GarageFinish'])
# Out:
# <AxesSubplot:xlabel='GarageFinish'>

# %%
sns.boxplot(df2['TotRmsAbvGrd'])
# Out:
# <AxesSubplot:xlabel='TotRmsAbvGrd'>

# %%
sns.boxplot(df2['GarageYrBlt'])
# Out:
# <AxesSubplot:xlabel='GarageYrBlt'>

# %%
sns.boxplot(df2['KitchenQual'])
# Out:
# <AxesSubplot:xlabel='KitchenQual'>

# %%
sns.boxplot(df2['BsmtHalfBath'])
# Out:
# <AxesSubplot:xlabel='BsmtHalfBath'>

# %%
sns.boxplot(df2['FullBath'])
# Out:
# <AxesSubplot:xlabel='FullBath'>

# %%
sns.boxplot(df2['HalfBath'])
# Out:
# <AxesSubplot:xlabel='HalfBath'>

# %%
sns.boxplot(df2['BedroomAbvGr'])
# Out:
# <AxesSubplot:xlabel='BedroomAbvGr'>

# %%
sns.boxplot(df2['KitchenAbvGr'])
# Out:
# <AxesSubplot:xlabel='KitchenAbvGr'>

# %%
sns.boxplot(df2['1stFlrSF'])
# Out:
# <AxesSubplot:xlabel='1stFlrSF'>

# %%
sns.boxplot(df2['2ndFlrSF'])
# Out:
# <AxesSubplot:xlabel='2ndFlrSF'>

# %%
sns.boxplot(df2['LowQualFinSF'])
# Out:
# <AxesSubplot:xlabel='LowQualFinSF'>

# %%
sns.boxplot(df2['GrLivArea'])
# Out:
# <AxesSubplot:xlabel='GrLivArea'>

# %%
sns.boxplot(df2['BsmtFullBath'])
# Out:
# <AxesSubplot:xlabel='BsmtFullBath'>

# %%
sns.boxplot(df2['Electrical'])
# Out:
# <AxesSubplot:xlabel='Electrical'>

# %%
sns.boxplot(df2['CentralAir'])
# Out:
# <AxesSubplot:xlabel='CentralAir'>

# %%
sns.boxplot(df2['HeatingQC'])
# Out:
# <AxesSubplot:xlabel='HeatingQC'>

# %%
sns.boxplot(df2['Heating'])
# Out:
# <AxesSubplot:xlabel='Heating'>

# %%
sns.boxplot(df2['TotalBsmtSF'])
# Out:
# <AxesSubplot:xlabel='TotalBsmtSF'>

# %%
sns.boxplot(df2['BsmtFinType1'])
# Out:
# <AxesSubplot:xlabel='BsmtFinType1'>

# %%
sns.boxplot(df2['BsmtFinSF1'])
# Out:
# <AxesSubplot:xlabel='BsmtFinSF1'>

# %%
sns.boxplot(df2['BsmtFinType2'])
# Out:
# <AxesSubplot:xlabel='BsmtFinType2'>

# %%
sns.boxplot(df2['BsmtFinSF2'])
# Out:
# <AxesSubplot:xlabel='BsmtFinSF2'>

# %%
sns.boxplot(df2['BsmtUnfSF'])
# Out:
# <AxesSubplot:xlabel='BsmtUnfSF'>

# %%
sns.boxplot(df2['BsmtExposure'])
# Out:
# <AxesSubplot:xlabel='BsmtExposure'>

# %%
sns.boxplot(df2['BsmtCond'])
# Out:
# <AxesSubplot:xlabel='BsmtCond'>

# %%
sns.boxplot(df2['BsmtQual'])
# Out:
# <AxesSubplot:xlabel='BsmtQual'>

# %%
sns.boxplot(df2['Foundation'])
# Out:
# <AxesSubplot:xlabel='Foundation'>

# %%
sns.boxplot(df2['ExterCond'])
# Out:
# <AxesSubplot:xlabel='ExterCond'>

# %%
sns.boxplot(df2['Exterior1st'])
# Out:
# <AxesSubplot:xlabel='Exterior1st'>

# %%
sns.boxplot(df2['Exterior2nd'])
# Out:
# <AxesSubplot:xlabel='Exterior2nd'>

# %%
sns.boxplot(df2['MasVnrType'])
# Out:
# <AxesSubplot:xlabel='MasVnrType'>

# %%
sns.boxplot(df2['ExterQual'])
# Out:
# <AxesSubplot:xlabel='ExterQual'>

# %%
sns.boxplot(df2['RoofMatl'])
# Out:
# <AxesSubplot:xlabel='RoofMatl'>

# %%
sns.boxplot(df2['RoofStyle'])
# Out:
# <AxesSubplot:xlabel='RoofStyle'>

# %%
sns.boxplot(df2['YearRemodAdd'])
# Out:
# <AxesSubplot:xlabel='YearRemodAdd'>

# %%
sns.boxplot(df2['YearBuilt'])
# Out:
# <AxesSubplot:xlabel='YearBuilt'>

# %%
sns.boxplot(df2['OverallCond'])
# Out:
# <AxesSubplot:xlabel='OverallCond'>

# %%
sns.boxplot(df2['Condition1'])
# Out:
# <AxesSubplot:xlabel='Condition1'>

# %%
sns.boxplot(df2['Condition2'])
# Out:
# <AxesSubplot:xlabel='Condition2'>

# %%
sns.boxplot(df2['BldgType'])
# Out:
# <AxesSubplot:xlabel='BldgType'>

# %%
sns.boxplot(df2['HouseStyle'])
# Out:
# <AxesSubplot:xlabel='HouseStyle'>

# %%
sns.boxplot(df2['OverallQual'])
# Out:
# <AxesSubplot:xlabel='OverallQual'>

# %%
sns.boxplot(df2['Neighborhood'])
# Out:
# <AxesSubplot:xlabel='Neighborhood'>

# %%
sns.boxplot(df2['LandSlope'])
# Out:
# <AxesSubplot:xlabel='LandSlope'>

# %%
sns.boxplot(df2['LotConfig'])
# Out:
# <AxesSubplot:xlabel='LotConfig'>

# %%
sns.boxplot(df2['LandContour'])
# Out:
# <AxesSubplot:xlabel='LandContour'>

# %%
sns.boxplot(df2['LotShape'])
# Out:
# <AxesSubplot:xlabel='LotShape'>

# %%
sns.boxplot(df2['MSZoning'])
# Out:
# <AxesSubplot:xlabel='MSZoning'>

# %%
sns.boxplot(df2['LotFrontage'])
# Out:
# <AxesSubplot:xlabel='LotFrontage'>

# %%
sns.boxplot(df2['LotArea'])
# Out:
# <AxesSubplot:xlabel='LotArea'>

# %%
sns.boxplot(df2['Street'])
# Out:
# <AxesSubplot:xlabel='Street'>

# %%
sns.boxplot(df2['MSSubClass'])
# Out:
# <AxesSubplot:xlabel='MSSubClass'>

# %% [markdown]
# ## SKEWNESSS CHECK

# %%
df2.skew()
# Out:
# MSSubClass        1.358597
# MSZoning          0.187174
# LotFrontage       0.466813
# LotArea          12.781805
# Street          -12.020386
#                    ...
# MiscVal          13.264758
# MoSold            0.186504
# YrSold            0.018412
# SaleType         -5.489874
# SaleCondition    -2.161104
# Length: 73, dtype: float64

# %% [markdown]
# ## SEPARATING X

# %%
x=df2.iloc[:,0:73]

# %%
x
# Out:
#      MSSubClass  MSZoning  LotFrontage  LotArea  Street  LotShape  \
# 0            20         2    86.000000    14157       1         0
# 1           120         2    66.425101     5814       1         0
# 2            20         2    66.425101    11838       1         3
# 3            70         2    75.000000    12000       1         3
# 4            60         2    86.000000    14598       1         0
# ..          ...       ...          ...      ...     ...       ...
# 287          20         2    78.000000    10206       1         3
# 288          20         2    57.000000     9245       1         1
# 289          20         2    66.425101    11241       1         0
# 290          50         3    50.000000     5000       1         3
# 291         160         3    21.000000     1953       1         3
#
#      LandContour  LotConfig  LandSlope  Neighborhood  ...  OpenPorchSF  \
# 0              1          0          0            21  ...           51
# ...

# %% [markdown]
# ## MULTICOLINEARITY CHECK

# %%
from scipy import stats

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
def cal_vif(x):
    vif=pd.DataFrame()
    vif['Variables']=x.columns
    vif['VIF_FACTOR']=[variance_inflation_factor(x.values,i)for i in range(x.shape[1])]
    return(vif)

# %%
cal_vif(x)
# Out:
#         Variables    VIF_FACTOR
# 0      MSSubClass     30.657597
# 1        MSZoning     39.189786
# 2     LotFrontage     32.300570
# 3         LotArea      4.119583
# 4          Street    240.905254
# ..            ...           ...
# 68        MiscVal      1.751571
# 69         MoSold      7.949464
# 70         YrSold  51448.874884
# 71       SaleType     69.432481
# 72  SaleCondition     20.632761
#
# [73 rows x 2 columns]

# %%
pd.set_option('display.max_rows',73)

# %%
cal_vif(x)
# Out:
#         Variables    VIF_FACTOR
# 0      MSSubClass  3.065760e+01
# 1        MSZoning  3.918979e+01
# 2     LotFrontage  3.230057e+01
# 3         LotArea  4.119583e+00
# 4          Street  2.409053e+02
# 5        LotShape  5.046003e+00
# 6     LandContour  2.981264e+01
# 7       LotConfig  6.788405e+00
# 8       LandSlope  2.857403e+00
# 9    Neighborhood  7.877441e+00
# 10     Condition1  9.246240e+00
# 11     Condition2  1.501779e+00
# 12       BldgType  9.019761e+00
# 13     HouseStyle  9.812152e+00
# 14    OverallQual  1.100525e+02
# 15    OverallCond  8.959937e+01
# 16      YearBuilt  4.329870e+04
# 17   YearRemodAdd  3.725832e+04
# 18      RoofStyle  6.528880e+00
# 19       RoofMatl  1.385427e+00
# 20    Exterior1st  6.124205e+01
# 21    Exterior2nd  5.481396e+01
# 22     MasVnrType  1.859824e+01
# 23     MasVnrArea  3.233156e+00
# 24      ExterQual  6.518539e+01
# 25      ExterCond  1.065380e+02
# 26     Foundation  1.280528e+01
# 27       BsmtQual  2.207715e+01
# ...

# %% [markdown]
# ### DROPPING BsmtFinSF1 AS THE VALUE IS INFINITE

# %%
x1=x.drop(['BsmtFinSF1'],axis=1)

# %%
def cal_vif(x1):
    vif=pd.DataFrame()
    vif['Variables']=x1.columns
    vif['VIF_FACTOR']=[variance_inflation_factor(x1.values,i)for i in range(x1.shape[1])]
    return(vif)

# %%
cal_vif(x1)
# Out:
#         Variables    VIF_FACTOR
# 0      MSSubClass  3.065760e+01
# 1        MSZoning  3.918979e+01
# 2     LotFrontage  3.230057e+01
# 3         LotArea  4.119583e+00
# 4          Street  2.409053e+02
# 5        LotShape  5.046003e+00
# 6     LandContour  2.981264e+01
# 7       LotConfig  6.788405e+00
# 8       LandSlope  2.857403e+00
# 9    Neighborhood  7.877441e+00
# 10     Condition1  9.246240e+00
# 11     Condition2  1.501779e+00
# 12       BldgType  9.019761e+00
# 13     HouseStyle  9.812152e+00
# 14    OverallQual  1.100525e+02
# 15    OverallCond  8.959937e+01
# 16      YearBuilt  4.329870e+04
# 17   YearRemodAdd  3.725832e+04
# 18      RoofStyle  6.528880e+00
# 19       RoofMatl  1.385427e+00
# 20    Exterior1st  6.124205e+01
# 21    Exterior2nd  5.481396e+01
# 22     MasVnrType  1.859824e+01
# 23     MasVnrArea  3.233156e+00
# 24      ExterQual  6.518539e+01
# 25      ExterCond  1.065380e+02
# 26     Foundation  1.280528e+01
# 27       BsmtQual  2.207715e+01
# ...

# %% [markdown]
# ## DROPPING 1stFlrSF AS THE VIF SCORE IS INFINTE

# %%
x2=x1.drop(['1stFlrSF'],axis=1)

# %%
def cal_vif(x2):
    vif=pd.DataFrame()
    vif['Variables']=x2.columns
    vif['VIF_FACTOR']=[variance_inflation_factor(x2.values,i)for i in range(x2.shape[1])]
    return(vif)

# %%
cal_vif(x2)
# Out:
#         Variables    VIF_FACTOR
# 0      MSSubClass     30.657597
# 1        MSZoning     39.189786
# 2     LotFrontage     32.300570
# 3         LotArea      4.119583
# 4          Street    240.905254
# 5        LotShape      5.046003
# 6     LandContour     29.812642
# 7       LotConfig      6.788405
# 8       LandSlope      2.857403
# 9    Neighborhood      7.877441
# 10     Condition1      9.246240
# 11     Condition2      1.501779
# 12       BldgType      9.019761
# 13     HouseStyle      9.812152
# 14    OverallQual    110.052476
# 15    OverallCond     89.599375
# 16      YearBuilt  43298.701085
# 17   YearRemodAdd  37258.323691
# 18      RoofStyle      6.528880
# 19       RoofMatl      1.385427
# 20    Exterior1st     61.242049
# 21    Exterior2nd     54.813956
# 22     MasVnrType     18.598241
# 23     MasVnrArea      3.233156
# 24      ExterQual     65.185391
# 25      ExterCond    106.538026
# 26     Foundation     12.805279
# 27       BsmtQual     22.077146
# ...

# %% [markdown]
# ## DROPPING YrSold AS THE VIF SCORE IS BEYOND 10

# %%
x3=x2.drop(['YrSold'],axis=1)

# %%
def cal_vif(x3):
    vif=pd.DataFrame()
    vif['Variables']=x3.columns
    vif['VIF_FACTOR']=[variance_inflation_factor(x3.values,i)for i in range(x3.shape[1])]
    return(vif)

# %%
cal_vif(x3)
# Out:
#         Variables    VIF_FACTOR
# 0      MSSubClass     30.557071
# 1        MSZoning     38.940763
# 2     LotFrontage     32.297137
# 3         LotArea      4.116169
# 4          Street    240.903717
# 5        LotShape      4.908457
# 6     LandContour     29.711983
# 7       LotConfig      6.746757
# 8       LandSlope      2.831082
# 9    Neighborhood      7.839111
# 10     Condition1      9.234975
# 11     Condition2      1.500432
# 12       BldgType      8.890214
# 13     HouseStyle      9.384251
# 14    OverallQual    108.623820
# 15    OverallCond     89.084271
# 16      YearBuilt  35395.126172
# 17   YearRemodAdd  32331.064795
# 18      RoofStyle      6.519331
# 19       RoofMatl      1.383751
# 20    Exterior1st     60.833793
# 21    Exterior2nd     53.396192
# 22     MasVnrType     18.558972
# 23     MasVnrArea      3.217797
# 24      ExterQual     63.543952
# 25      ExterCond    106.411918
# 26     Foundation     11.711359
# 27       BsmtQual     21.812244
# ...

# %% [markdown]
# ## DROPPING YearBuilt AS THE VIF SCORE IS BEYOND 10

# %%
x4=x3.drop(['YearBuilt'],axis=1)

# %%
def cal_vif(x4):
    vif=pd.DataFrame()
    vif['Variables']=x4.columns
    vif['VIF_FACTOR']=[variance_inflation_factor(x4.values,i)for i in range(x4.shape[1])]
    return(vif)

# %%
cal_vif(x4)
# Out:
#         Variables    VIF_FACTOR
# 0      MSSubClass     30.416371
# 1        MSZoning     38.827575
# 2     LotFrontage     30.991867
# 3         LotArea      4.114981
# 4          Street    240.637868
# 5        LotShape      4.861375
# 6     LandContour     29.559522
# 7       LotConfig      6.746540
# 8       LandSlope      2.830448
# 9    Neighborhood      7.822123
# 10     Condition1      9.195034
# 11     Condition2      1.489444
# 12       BldgType      8.882960
# 13     HouseStyle      9.384193
# 14    OverallQual    108.530205
# 15    OverallCond     75.237555
# 16   YearRemodAdd  22860.108106
# 17      RoofStyle      6.512723
# 18       RoofMatl      1.362776
# 19    Exterior1st     59.480475
# 20    Exterior2nd     52.804321
# 21     MasVnrType     18.506861
# 22     MasVnrArea      3.217610
# 23      ExterQual     63.456969
# 24      ExterCond    102.382159
# 25     Foundation     11.632975
# 26       BsmtQual     21.637179
# 27       BsmtCond     45.456951
# ...

# %% [markdown]
# ## DROPPING YearRemodAdd AS THE VIF SCORE IS BEYOND 10

# %%
x5=x4.drop(['YearRemodAdd'],axis=1)

# %%
def cal_vif(x5):
    vif=pd.DataFrame()
    vif['Variables']=x5.columns
    vif['VIF_FACTOR']=[variance_inflation_factor(x5.values,i)for i in range(x5.shape[1])]
    return(vif)

# %%
cal_vif(x5)
# Out:
#         Variables   VIF_FACTOR
# 0      MSSubClass    30.386243
# 1        MSZoning    38.478179
# 2     LotFrontage    30.905402
# 3         LotArea     4.114023
# 4          Street   240.635780
# 5        LotShape     4.860112
# 6     LandContour    29.149254
# 7       LotConfig     6.743750
# 8       LandSlope     2.798058
# 9    Neighborhood     7.630911
# 10     Condition1     9.193518
# 11     Condition2     1.489439
# 12       BldgType     8.881186
# 13     HouseStyle     9.368444
# 14    OverallQual   108.014025
# 15    OverallCond    65.986688
# 16      RoofStyle     6.499477
# 17       RoofMatl     1.361821
# 18    Exterior1st    59.238796
# 19    Exterior2nd    51.338088
# 20     MasVnrType    18.496128
# 21     MasVnrArea     3.179440
# 22      ExterQual    63.427912
# 23      ExterCond   101.906911
# 24     Foundation    11.502053
# 25       BsmtQual    21.613133
# 26       BsmtCond    45.092868
# 27   BsmtExposure    10.320093
# 28   BsmtFinType1     8.104552
# ...

# %% [markdown]
# ## DROPPING GarageYrBlt AS THE VIF SCORE IS BEYOND 10

# %%
x6=x5.drop(['GarageYrBlt'],axis=1)

# %%
def cal_vif(x6):
    vif=pd.DataFrame()
    vif['Variables']=x6.columns
    vif['VIF_FACTOR']=[variance_inflation_factor(x6.values,i)for i in range(x6.shape[1])]
    return(vif)

# %%
cal_vif(x6)
# Out:
#         Variables  VIF_FACTOR
# 0      MSSubClass   29.632185
# 1        MSZoning   37.690004
# 2     LotFrontage   30.591107
# 3         LotArea    3.983172
# 4          Street  195.147440
# 5        LotShape    4.844612
# 6     LandContour   28.635887
# 7       LotConfig    6.742139
# 8       LandSlope    2.690027
# 9    Neighborhood    7.596909
# 10     Condition1    9.045226
# 11     Condition2    1.489355
# 12       BldgType    8.813128
# 13     HouseStyle    9.364762
# 14    OverallQual  106.110985
# 15    OverallCond   62.342798
# 16      RoofStyle    6.411460
# 17       RoofMatl    1.360242
# 18    Exterior1st   59.133893
# 19    Exterior2nd   50.158070
# 20     MasVnrType   18.290220
# 21     MasVnrArea    3.178782
# 22      ExterQual   63.374071
# 23      ExterCond   88.118107
# 24     Foundation   11.376780
# 25       BsmtQual   21.107717
# 26       BsmtCond   43.742926
# 27   BsmtExposure   10.163715
# 28   BsmtFinType1    7.692543
# 29   BsmtFinType2   83.808563
# ...

# %% [markdown]
# ## DROPPING Street AS THE VIF SCORE IS BEYOND 10

# %%
x7=x6.drop(['Street'],axis=1)

# %%
def cal_vif(x7):
    vif=pd.DataFrame()
    vif['Variables']=x7.columns
    vif['VIF_FACTOR']=[variance_inflation_factor(x7.values,i)for i in range(x7.shape[1])]
    return(vif)

# %%
cal_vif(x7)
# Out:
#         Variables  VIF_FACTOR
# 0      MSSubClass   29.521659
# 1        MSZoning   37.633724
# 2     LotFrontage   30.468378
# 3         LotArea    3.955607
# 4        LotShape    4.839888
# 5     LandContour   28.378926
# 6       LotConfig    6.695381
# 7       LandSlope    2.485816
# 8    Neighborhood    7.582185
# 9      Condition1    8.613221
# 10     Condition2    1.485722
# 11       BldgType    8.799240
# 12     HouseStyle    9.309133
# 13    OverallQual  104.955599
# 14    OverallCond   61.691301
# 15      RoofStyle    6.409403
# 16       RoofMatl    1.356008
# 17    Exterior1st   58.950967
# 18    Exterior2nd   49.723035
# 19     MasVnrType   17.870382
# 20     MasVnrArea    3.164841
# 21      ExterQual   59.821140
# 22      ExterCond   83.986105
# 23     Foundation   11.351782
# 24       BsmtQual   20.913823
# 25       BsmtCond   43.610554
# 26   BsmtExposure   10.148680
# 27   BsmtFinType1    7.687937
# 28   BsmtFinType2   81.807460
# 29     BsmtFinSF2    4.246663
# ...

# %% [markdown]
# ## DROPPING GrLivArea AS THE VIF SCORE IS GREATER THAN 10

# %%
x8=x7.drop(['GrLivArea'],axis=1)

# %%
def cal_vif(x8):
    vif=pd.DataFrame()
    vif['Variables']=x8.columns
    vif['VIF_FACTOR']=[variance_inflation_factor(x8.values,i)for i in range(x8.shape[1])]
    return(vif)

# %%
cal_vif(x8)
# Out:
#         Variables  VIF_FACTOR
# 0      MSSubClass   29.499361
# 1        MSZoning   37.411316
# 2     LotFrontage   30.397879
# 3         LotArea    3.939859
# 4        LotShape    4.820751
# 5     LandContour   28.367815
# 6       LotConfig    6.692254
# 7       LandSlope    2.465140
# 8    Neighborhood    7.229244
# 9      Condition1    8.575456
# 10     Condition2    1.485719
# 11       BldgType    8.787236
# 12     HouseStyle    8.848602
# 13    OverallQual  102.134861
# 14    OverallCond   60.963064
# 15      RoofStyle    6.404845
# 16       RoofMatl    1.351899
# 17    Exterior1st   58.602094
# 18    Exterior2nd   49.371330
# 19     MasVnrType   17.673948
# 20     MasVnrArea    3.146344
# 21      ExterQual   59.092556
# 22      ExterCond   83.360304
# 23     Foundation   11.245880
# 24       BsmtQual   20.895539
# 25       BsmtCond   43.587632
# 26   BsmtExposure   10.118320
# 27   BsmtFinType1    7.658487
# 28   BsmtFinType2   79.513486
# 29     BsmtFinSF2    4.142851
# ...

# %% [markdown]
# ## DROPPING OverallQual AS THE VIF SCORE IS GREATER THAN 10

# %%
x9=x8.drop(['OverallQual'],axis=1)

# %%
def cal_vif(x9):
    vif=pd.DataFrame()
    vif['Variables']=x9.columns
    vif['VIF_FACTOR']=[variance_inflation_factor(x9.values,i)for i in range(x9.shape[1])]
    return(vif)

# %%
cal_vif(x9)
# Out:
#         Variables  VIF_FACTOR
# 0      MSSubClass   29.249375
# 1        MSZoning   37.251647
# 2     LotFrontage   30.359717
# 3         LotArea    3.909047
# 4        LotShape    4.819232
# 5     LandContour   27.723570
# 6       LotConfig    6.678944
# 7       LandSlope    2.449621
# 8    Neighborhood    7.008846
# 9      Condition1    8.573962
# 10     Condition2    1.480116
# 11       BldgType    8.745505
# 12     HouseStyle    8.834780
# 13    OverallCond   59.955185
# 14      RoofStyle    6.393304
# 15       RoofMatl    1.351797
# 16    Exterior1st   58.568963
# 17    Exterior2nd   49.340372
# 18     MasVnrType   17.673391
# 19     MasVnrArea    3.144405
# 20      ExterQual   57.771921
# 21      ExterCond   77.432057
# 22     Foundation   11.116628
# 23       BsmtQual   20.527505
# 24       BsmtCond   43.555523
# 25   BsmtExposure   10.109396
# 26   BsmtFinType1    7.402614
# 27   BsmtFinType2   77.598114
# 28     BsmtFinSF2    4.138955
# 29      BsmtUnfSF   11.880571
# ...

# %% [markdown]
# ## DROPPING GarageCond AS THE VIF SCORE IS BEYOND 10

# %%
x10=x9.drop(['GarageCond'],axis=1)

# %%
def cal_vif(x10):
    vif=pd.DataFrame()
    vif['Variables']=x10.columns
    vif['VIF_FACTOR']=[variance_inflation_factor(x10.values,i)for i in range(x10.shape[1])]
    return(vif)

# %%
cal_vif(x10)
# Out:
#         Variables  VIF_FACTOR
# 0      MSSubClass   28.896354
# 1        MSZoning   37.075668
# 2     LotFrontage   30.309289
# 3         LotArea    3.903061
# 4        LotShape    4.818456
# 5     LandContour   27.536207
# 6       LotConfig    6.640477
# 7       LandSlope    2.426616
# 8    Neighborhood    7.001656
# 9      Condition1    8.570258
# 10     Condition2    1.411649
# 11       BldgType    8.700872
# 12     HouseStyle    8.833087
# 13    OverallCond   59.927157
# 14      RoofStyle    6.388771
# 15       RoofMatl    1.329578
# 16    Exterior1st   58.568559
# 17    Exterior2nd   49.240876
# 18     MasVnrType   17.589923
# 19     MasVnrArea    3.132237
# 20      ExterQual   57.744390
# 21      ExterCond   77.428597
# 22     Foundation   10.910194
# 23       BsmtQual   20.523743
# 24       BsmtCond   42.384567
# 25   BsmtExposure   10.102164
# 26   BsmtFinType1    7.354469
# 27   BsmtFinType2   77.504188
# 28     BsmtFinSF2    4.136082
# 29      BsmtUnfSF   11.858363
# ...

# %% [markdown]
# ## WE HAVE DROPPED 10 COLUMNS AS THE VIF SCORES WERE VEERY HIGH, VIF SCORE IS STILL BEYOND 10 IN THIS BUT WE WILL GO AHEAD ANYWAY AS WE DONT WANT TO MISS OUT ON ANY IMPORTANT FEATURES FOR PREDICTION

# %% [markdown]
# ## SKEWNESS REMOVAL

# %%
from sklearn.preprocessing import power_transform

# %%
xnew=power_transform(x10)

# %%
a=pd.DataFrame(xnew, columns=x10.columns).skew().sort_values(ascending=True)

# %%
a
# Out:
# GarageQual       -4.253614
# BsmtCond         -4.085599
# Functional       -3.793144
# CentralAir       -3.792878
# PavedDrive       -3.143668
# SaleType         -3.059359
# LandContour      -2.829769
# BsmtFinType2     -2.582706
# ExterCond        -2.512541
# LotConfig        -1.045888
# BsmtExposure     -1.011543
# ExterQual        -0.700849
# LotShape         -0.623034
# KitchenQual      -0.505401
# RoofStyle        -0.472902
# BsmtQual         -0.458413
# Exterior2nd      -0.364171
# GarageArea       -0.361092
# GarageFinish     -0.319091
# Electrical       -0.315323
# Exterior1st      -0.281575
# BsmtUnfSF        -0.232099
# BsmtFinType1     -0.168838
# Neighborhood     -0.157737
# OverallCond      -0.079098
# HouseStyle       -0.067515
# FullBath         -0.064123
# OpenPorchSF      -0.058951
# MoSold           -0.053915
# TotalBsmtSF      -0.037982
# GarageCars       -0.030495
# MasVnrType       -0.025474
# TotRmsAbvGrd     -0.000469
# PoolArea          0.000000
# ...

# %% [markdown]
# ## MOST OF THE DATA SET HAS CATAGORICAL VARIABLES WHICH HAVE HIGH SKEWENSS WHICH WE WILL NOTT DISTURB AND SOME INT/FLOAT VARIABLES TOO HAVE SKEWENSS WHICH HAVE BEEN REDUCED BUT NOT FULLY, HENCE WE WILL CONTINUE WITH THIS

# %% [markdown]
# ## USING PRINCIPAL COMPONENT ANALYSIS AS THE NUMBER OF COLUMNS ARE EXTREMELY HIGH

# %%
from sklearn.decomposition import PCA

# %%
pca=PCA(n_components=50)

# %%
xpca=pca.fit_transform(xnew)

# %%
xpca.shape
# Out:
# (292, 45)

# %% [markdown]
# ## SCALING

# %% [markdown]
# ### SINCE WE HAVE USED POWER TRANSFORM IN OUR DATA SET WHILE REMOVING SKEWNESS, OUR DATA IS ALREADY SCALED, HENCE NO NEED TO SCALE AGAIN

# %% [markdown]
# ## PREDICTING THE DATA USING GRADIENT BOOSTING REGRESSOR

# %%
import pickle

# %%
filename='housing.pkl'
loaded_modelhsg1=pickle.load(open('housing.pkl','rb'))

# %%
PREDICTED=loaded_modelhsg1.predict(xpca)

# %%
PREDICTEDFILE=pd.Series(data=PREDICTED)

# %%
PREDICTEDFILE
# Out:
# 0      370161.649783
# 1      164408.839111
# 2      264804.850475
# 3      173431.418191
# 4      288657.860367
#            ...
# 287    227999.998882
# 288    142818.952277
# 289    162124.563700
# 290    135968.959333
# 291    106178.492678
# Length: 292, dtype: float64

# %%
PREDICTEDFILE.to_csv('PREDICTEDHOUSINGFILE.csv')
